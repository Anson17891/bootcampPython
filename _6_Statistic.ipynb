# %%
# max/min/sum/len
# median/sd/var

import statistics

numbers = [20, 10, 90, 99, 40, 25, 90]
print(statistics.median(numbers))
print(statistics.mean(numbers))
print(statistics.stdev(numbers))
print(statistics.mode(numbers))

# %%
import math

print(math.sqrt(9))
print(math.sqrt(9.5))
print(math.pow(3,4))
print(math.pow(3,4.5))

# %%
from decimal import Decimal

print(Decimal(str(0.1)) + Decimal(str(0.2))) #BigDecimal, kind of tedious
